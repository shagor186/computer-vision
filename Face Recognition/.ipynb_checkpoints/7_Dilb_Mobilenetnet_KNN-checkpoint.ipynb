# %%
# -*- coding: utf-8 -*-
"""
Face Recognition Pipeline (dlib -> MobileNetV2 -> KNN)
Features:
- Multi-format image support (png, webp, jpg, jpeg, bmp)
- Auto-convert non-jpg to .jpg
- Remove unreadable/corrupt images
- Remove images with no detected face
- Face crop + resize (224x224)
- Generate MobileNetV2 embeddings
- Train KNN classifier
- Save/load model
- Confusion matrix, classification report
- Single image prediction
"""

import os
import cv2 as cv
import numpy as np
from PIL import Image
import dlib
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.utils.multiclass import unique_labels
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import warnings
warnings.filterwarnings("ignore")

# TensorFlow/Keras imports
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D

# ----------------------------
# Config
# ----------------------------
TARGET_SIZE = (224, 224)  # MobileNetV2 default input
ALLOWED_EXT = ('.jpg', '.jpeg', '.png', '.webp', '.bmp')
SAVED_MODEL_PATH = 'knn_mobilenet_face_model.pkl'
EMBEDDING_BATCH_SAVE = None  # Optional

# ----------------------------
# MobileNetV2 Feature Extractor
# ----------------------------
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224,224,3))
x = GlobalAveragePooling2D()(base_model.output)
feature_extractor = Model(inputs=base_model.input, outputs=x)

def get_embedding(face_img):
    """
    face_img: RGB uint8 numpy array 224x224x3
    returns 1280-D float32 embedding
    """
    img = cv.cvtColor(face_img, cv.COLOR_BGR2RGB) if face_img.shape[2]==3 else face_img
    img = cv.resize(img, TARGET_SIZE)
    img = preprocess_input(img.astype('float32'))
    img = np.expand_dims(img, axis=0)
    emb = feature_extractor.predict(img, verbose=0)
    return emb[0]

# ----------------------------
# FACELOADING Class
# ----------------------------
class FACELOADING:
    def __init__(self, directory, target_size=TARGET_SIZE):
        self.directory = directory
        self.target_size = target_size
        self.detector = dlib.get_frontal_face_detector()
        self.X = []
        self.Y = []

    def read_and_convert(self, filepath):
        try:
            img = Image.open(filepath).convert("RGB")
        except Exception as e:
            print(f"❌ Bad image removed: {filepath} ({e})")
            try: os.remove(filepath)
            except: pass
            return None, None

        ext = os.path.splitext(filepath)[1].lower()
        if ext not in ('.jpg', '.jpeg'):
            new_path = os.path.splitext(filepath)[0] + ".jpg"
            try:
                img.save(new_path, "JPEG", quality=95)
                if new_path != filepath:
                    try: os.remove(filepath)
                    except: pass
                filepath = new_path
            except Exception as e:
                print(f"❌ Conversion failed: {filepath} ({e})")
                return None, None

        img_np = np.array(img)
        return img_np, filepath

    def extract_face(self, filepath):
        img_rgb, final_path = self.read_and_convert(filepath)
        if img_rgb is None: return None

        faces = self.detector(img_rgb, 1)
        if not faces:
            print(f"⚠️ No face found: {final_path}")
            return None

        d = faces[0]
        x1, y1, x2, y2 = max(d.left(),0), max(d.top(),0), min(d.right(), img_rgb.shape[1]), min(d.bottom(), img_rgb.shape[0])
        face = img_rgb[y1:y2, x1:x2]

        if face.size == 0 or face.shape[0] < 10 or face.shape[1] < 10:
            print(f"⚠️ Tiny/invalid face crop: {final_path}")
            return None

        face_resized = cv.resize(face, self.target_size)
        return face_resized

    def load_faces_from_class(self, class_dir):
        faces = []
        for fname in os.listdir(class_dir):
            fullpath = os.path.join(class_dir, fname)
            if not os.path.isfile(fullpath):
                continue
            face = self.extract_face(fullpath)
            if face is not None:
                faces.append(face)
        return faces

    def load_classes(self):
        for sub in sorted(os.listdir(self.directory)):
            subpath = os.path.join(self.directory, sub)
            if not os.path.isdir(subpath):
                continue
            faces = self.load_faces_from_class(subpath)
            labels = [sub] * len(faces)
            print(f"✅ Loaded {len(faces)} valid faces for class '{sub}'")
            self.X.extend(faces)
            self.Y.extend(labels)

        X_arr = np.asarray(self.X) if self.X else np.empty((0, *self.target_size, 3))
        Y_arr = np.asarray(self.Y) if self.Y else np.array([])
        return X_arr, Y_arr

    def plot_samples(self, limit=12):
        import math
        if len(self.X) == 0:
            print("No images to show.")
            return
        n = min(limit, len(self.X))
        cols = 4
        rows = math.ceil(n / cols)
        plt.figure(figsize=(cols * 3, rows * 3))
        for i in range(n):
            plt.subplot(rows, cols, i + 1)
            plt.imshow(self.X[i])
            plt.axis('off')
        plt.show()

# ----------------------------
# Train KNN
# ----------------------------
def train_knn_with_metrics(EMBEDDED_X, Y_labels, test_size=0.25, random_state=17, k_neighbors=3):
    encoder = LabelEncoder()
    Y_enc = encoder.fit_transform(Y_labels)

    from collections import Counter
    counts = Counter(Y_enc)
    if min(counts.values()) < 2:
        stratify_param = None
        print("⚠️ Dataset too small for stratify, training without stratify")
    else:
        stratify_param = Y_enc

    X_train, X_test, Y_train, Y_test = train_test_split(
        EMBEDDED_X, Y_enc, test_size=test_size, random_state=random_state, stratify=stratify_param
    )

    model = KNeighborsClassifier(n_neighbors=k_neighbors)
    model.fit(X_train, Y_train)

    Y_train_pred = model.predict(X_train)
    Y_test_pred = model.predict(X_test)

    print("\n🔹 Training Results:")
    print(f"Train Accuracy : {accuracy_score(Y_train, Y_train_pred):.4f}")
    print(f"Test Accuracy  : {accuracy_score(Y_test, Y_test_pred):.4f}")

    target_names = [encoder.classes_[i] for i in sorted(unique_labels(Y_test, Y_test_pred))]
    print("\n📄 Classification Report:")
    print(classification_report(Y_test, Y_test_pred, target_names=target_names))

    cm = confusion_matrix(Y_test, Y_test_pred, labels=sorted(unique_labels(Y_test, Y_test_pred)))
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=target_names, yticklabels=target_names)
    plt.title("Confusion Matrix")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.show()

    return model, encoder

# ----------------------------
# Predict single image
# ----------------------------
def predict_image_from_path(model, encoder, image_path):
    detector = dlib.get_frontal_face_detector()
    try:
        img = Image.open(image_path).convert("RGB")
    except Exception as e:
        print(f"Cannot open image: {e}")
        return None

    img_np = np.array(img)
    faces = detector(img_np, 1)
    if not faces:
        print("No face detected in test image.")
        return None

    d = faces[0]
    x1, y1, x2, y2 = max(d.left(),0), max(d.top(),0), min(d.right(), img_np.shape[1]), min(d.bottom(), img_np.shape[0])
    face = img_np[y1:y2, x1:x2]
    face_resized = cv.resize(face, TARGET_SIZE)

    emb = get_embedding(face_resized).reshape(1, -1)
    pred = model.predict(emb)
    prob = np.max(model.predict_proba(emb))
    name = encoder.inverse_transform(pred)[0]
    print(f"Predicted: {name}  (prob: {prob:.3f})")
    return name, prob

# ----------------------------
# Save / Load Model
# ----------------------------
def save_model_and_encoder(model, encoder, path=SAVED_MODEL_PATH):
    with open(path, 'wb') as f:
        pickle.dump({'model': model, 'encoder': encoder}, f)
    print(f"Model & encoder saved to {path}")

def load_model_and_encoder(path=SAVED_MODEL_PATH):
    with open(path, 'rb') as f:
        data = pickle.load(f)
    return data['model'], data['encoder']

# ----------------------------
# Full pipeline
# ----------------------------
def run_pipeline(train_dir, test_image_path=None, plot_samples=True):
    loader = FACELOADING(train_dir, target_size=TARGET_SIZE)
    X_images, Y_labels = loader.load_classes()
    if X_images.size == 0:
        print("No valid faces found in training directory.")
        return

    if plot_samples:
        loader.plot_samples(limit=12)

    print("⚙️ Generating embeddings (MobileNetV2, may take a while)...")
    EMBEDDED = np.array([get_embedding(img) for img in X_images])

    if EMBEDDING_BATCH_SAVE:
        np.save(EMBEDDING_BATCH_SAVE, EMBEDDED)
        print(f"Saved embeddings to {EMBEDDING_BATCH_SAVE}.npy")

    model, encoder = train_knn_with_metrics(EMBEDDED, Y_labels)
    save_model_and_encoder(model, encoder)

    if test_image_path:
        print("\n🔎 Predicting test image...")
        predict_image_from_path(model, encoder, test_image_path)

    return model, encoder

# ----------------------------
# Run example
# ----------------------------
if __name__ == "__main__":
    train_dir = "dataset/train"       
    test_image = "dataset/test/ronaldo/ronaldo.jpg"

    run_pipeline(train_dir, test_image_path=test_image, plot_samples=True)
# Out:
# 2025-11-07 15:38:51.662171: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-07 15:38:51.662457: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-07 15:38:51.700573: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-07 15:38:53.041069: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ✅ Loaded 5 valid faces for class 'aqidi'
# ⚠️ No face found: dataset/train/bale/4.jpg
# ✅ Loaded 4 valid faces for class 'bale'
# ✅ Loaded 5 valid faces for class 'brozovic'
# ⚠️ No face found: dataset/train/bruyne/1.jpg
# ✅ Loaded 5 valid faces for class 'bruyne'
# ⚠️ No face found: dataset/train/cancelo/3.jpg
# ⚠️ No face found: dataset/train/cancelo/5.jpg
# ⚠️ No face found: dataset/train/cancelo/4.jpg
# ⚠️ No face found: dataset/train/cancelo/6.jpg
# ✅ Loaded 2 valid faces for class 'cancelo'
# ⚠️ No face found: dataset/train/casimiro/3.jpg
# ✅ Loaded 4 valid faces for class 'casimiro'
# ⚠️ No face found: dataset/train/costa/2.jpg
# ✅ Loaded 3 valid faces for class 'costa'
# ⚠️ No face found: dataset/train/cummins/2.jpg
# ✅ Loaded 2 valid faces for class 'cummins'
# ✅ Loaded 5 valid faces for class 'deligt'
# ⚠️ No face found: dataset/train/dias/3.jpg
# ⚠️ No face found: dataset/train/dias/6.jpg
# ✅ Loaded 4 valid faces for class 'dias'
# ✅ Loaded 5 valid faces for class 'fernandes'
# ⚠️ No face found: dataset/train/gordon/1.jpg
# ⚠️ No face found: dataset/train/gordon/3.jpg
# ✅ Loaded 3 valid faces for class 'gordon'
# ⚠️ No face found: dataset/train/haaland/3.jpg
# ✅ Loaded 4 valid faces for class 'haaland'
# ⚠️ No face found: dataset/train/kohli/2.jpg
# ✅ Loaded 4 valid faces for class 'kohli'
# ⚠️ No face found: dataset/train/mane/1.jpg
# ⚠️ No face found: dataset/train/mane/5.jpg
# ⚠️ No face found: dataset/train/mane/4.jpg
# ⚠️ No face found: dataset/train/mane/6.jpg
# ✅ Loaded 1 valid faces for class 'mane'
# ✅ Loaded 5 valid faces for class 'marcelo'
# ✅ Loaded 6 valid faces for class 'mbappe'
# ✅ Loaded 5 valid faces for class 'mendes'
# ⚠️ No face found: dataset/train/messi/1.jpg
# ⚠️ No face found: dataset/train/messi/4.jpg
# ⚠️ No face found: dataset/train/messi/6.jpg
# ✅ Loaded 3 valid faces for class 'messi'
# ⚠️ No face found: dataset/train/ozil/7.jpg
# ⚠️ No face found: dataset/train/ozil/1.jpg
# ⚠️ No face found: dataset/train/ozil/2.jpg
# ✅ Loaded 4 valid faces for class 'ozil'
# ⚠️ No face found: dataset/train/pepe/1.jpg
# ⚠️ No face found: dataset/train/pepe/5.jpg
# ✅ Loaded 3 valid faces for class 'pepe'
# ⚠️ No face found: dataset/train/pickford/2.jpg
# ✅ Loaded 5 valid faces for class 'pickford'
# ✅ Loaded 6 valid faces for class 'ramos'
# ⚠️ No face found: dataset/train/rodriguez/1.jpg
# ⚠️ No face found: dataset/train/rodriguez/5.jpg
# ✅ Loaded 3 valid faces for class 'rodriguez'
# ⚠️ No face found: dataset/train/ronaldo/1.jpg
# ✅ Loaded 5 valid faces for class 'ronaldo'
# ⚠️ No face found: dataset/train/saka/2.jpg
# ⚠️ No face found: dataset/train/saka/4.jpg
# ✅ Loaded 2 valid faces for class 'saka'
# ✅ Loaded 3 valid faces for class 'shelton'
# ✅ Loaded 3 valid faces for class 'sinner'
# ✅ Loaded 5 valid faces for class 'trent'
# ⚠️ No face found: dataset/train/vitinha/1.jpg
# ✅ Loaded 4 valid faces for class 'vitinha'
# ⚙️ Generating embeddings (MobileNetV2, may take a while)...
# ⚠️ Dataset too small for stratify, training without stratify
#
# 🔹 Training Results:
# Train Accuracy : 0.3864
# Test Accuracy  : 0.1333
#
# 📄 Classification Report:
#               precision    recall  f1-score   support
#
#        aqidi       0.11      1.00      0.20         1
#         bale       0.00      0.00      0.00         0
#     brozovic       0.12      0.50      0.20         2
#       bruyne       1.00      0.50      0.67         2
#     casimiro       0.00      0.00      0.00         1
#      cummins       0.00      0.00      0.00         1
#       deligt       0.00      0.00      0.00         1
#         dias       0.00      0.00      0.00         1
#    fernandes       0.00      0.00      0.00         1
#       gordon       0.00      0.00      0.00         1
#      haaland       0.00      0.00      0.00         1
#        kohli       0.00      0.00      0.00         0
#         mane       0.00      0.00      0.00         1
#      marcelo       0.00      0.00      0.00         2
#       mbappe       0.33      0.50      0.40         2
#       mendes       0.00      0.00      0.00         2
#        messi       0.00      0.00      0.00         0
#         ozil       0.00      0.00      0.00         1
#         pepe       0.00      0.00      0.00         2
#     pickford       0.00      0.00      0.00         2
#        ramos       0.00      0.00      0.00         2
#         saka       0.00      0.00      0.00         0
#       sinner       0.00      0.00      0.00         1
#        trent       0.00      0.00      0.00         2
#      vitinha       0.00      0.00      0.00         1
#
#     accuracy                           0.13        30
#    macro avg       0.06      0.10      0.06        30
# weighted avg       0.10      0.13      0.09        30
# Model & encoder saved to knn_mobilenet_face_model.pkl
#
# 🔎 Predicting test image...
# Predicted: pickford  (prob: 0.333)
